# %% [markdown]
# # Loading the dataset

# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:#Oreoluwa383@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
# ...

# %%
# %%sql
#
# SELECT *
# FROM
#     Access_to_Basic_Services
# LIMIT 100;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 100 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
# ...

# %%
# %%sql
# --to shorten to 10
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '--to shorten to 10\nSELECT \n    *\nFROM\n    Access_to_Basic_Services\nLIMIT 10' at line 1")
# [SQL: --to shorten to 10
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 10;]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %%sql
# --to view unique country
#
# SELECT DISTINCT
#     Country_name
# FROM
#     Access_to_Basic_Services
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '--to view unique country\n\nSELECT DISTINCT\n    Country_name\nFROM\n    Access_to_Ba' at line 1")
# [SQL: --to view unique country
#
# SELECT DISTINCT
#     Country_name
# FROM
#     Access_to_Basic_Services
# LIMIT 10;]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %%sql
#
# CREATE TABLE County(Country VARCHAR(255));
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# (pymysql.err.OperationalError) (1050, "Table 'county' already exists")
# [SQL: CREATE TABLE County(Country VARCHAR(255));]
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
# %%sql
# INSERT INTO County(Country)
#
# SELECT DISTINCT
#     Country_name
# FROM
#     Access_to_Basic_Services
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 10 rows affected.
# []

# %%
# %%sql
# INSERT INTO County(Country)
#
# SELECT DISTINCT
#     Country_name
# FROM
#     Access_to_Basic_Services
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 182 rows affected.
# []

# %%
# %%sql
# --country_name, time_period, and pct_managed_drinking_water_services fields from the Access_to_Basic_Services table.
#
#
# SELECT
# Country_name,
# Time_period,
# pct_managed_drinking_water_services
# FROM
# Access_to_Basic_Services
# WHERE
# Time_period = 2020;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '--country_name, time_period, and pct_managed_drinking_water_services fields from' at line 1")
# [SQL: --country_name, time_period, and pct_managed_drinking_water_services fields from the Access_to_Basic_Services table.
#
#
# SELECT
# Country_name,
# Time_period,
# pct_managed_drinking_water_services
# FROM
# Access_to_Basic_Services
# WHERE
# Time_period = 2020;]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %%sql
# SELECT
# Country_name,
# Time_period,
# pct_managed_drinking_water_services AS pct_access_to_water
# FROM
# Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Kazakhstan', 2015, Decimal('94.67')),
#  ('Kazakhstan', 2016, Decimal('94.67')),
#  ('Kazakhstan', 2017, Decimal('95.00')),
#  ('Kazakhstan', 2018, Decimal('95.00')),
#  ('Kazakhstan', 2019, Decimal('95.00')),
#  ('Kazakhstan', 2020, Decimal('95.00')),
#  ('Kyrgyzstan', 2015, Decimal('89.67')),
#  ('Kyrgyzstan', 2016, Decimal('90.33')),
#  ('Kyrgyzstan', 2017, Decimal('91.00')),
#  ('Kyrgyzstan', 2018, Decimal('91.33')),
#  ('Kyrgyzstan', 2019, Decimal('91.67')),
#  ('Kyrgyzstan', 2020, Decimal('92.67')),
#  ('Tajikistan', 2015, Decimal('80.33')),
#  ('Tajikistan', 2016, Decimal('81.33')),
#  ('Tajikistan', 2017, Decimal('82.33')),
#  ('Tajikistan', 2018, Decimal('83.33')),
#  ('Tajikistan', 2019, Decimal('85.00')),
#  ('Tajikistan', 2020, Decimal('85.00')),
#  ('Turkmenistan', 2015, Decimal('97.67')),
#  ('Turkmenistan', 2016, Decimal('98.00')),
#  ('Turkmenistan', 2017, Decimal('98.67')),
# ...

# %%
# %%sql
#
# SELECT
#
# Country_name,
# Time_period,
# pct_managed_drinking_water_services
# FROM
# Access_to_Basic_Services
# WHERE
# Time_period = 2020
# LIMIT 30;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 30 rows affected.
# [('Kazakhstan', 2020, Decimal('95.00')),
#  ('Kyrgyzstan', 2020, Decimal('92.67')),
#  ('Tajikistan', 2020, Decimal('85.00')),
#  ('Turkmenistan', 2020, Decimal('100.00')),
#  ('Uzbekistan', 2020, Decimal('98.00')),
#  ('Afghanistan', 2020, Decimal('80.33')),
#  ('Bangladesh', 2020, Decimal('97.67')),
#  ('Bhutan', 2020, Decimal('97.33')),
#  ('India', 2020, Decimal('91.00')),
#  ('Iran (Islamic Republic of)', 2020, Decimal('96.67')),
#  ('Maldives', 2020, Decimal('99.67')),
#  ('Nepal', 2020, Decimal('90.00')),
#  ('Pakistan', 2020, Decimal('90.67')),
#  ('Sri Lanka', 2020, Decimal('94.33')),
#  ('China', 2020, Decimal('93.67')),
#  ("Democratic People's Republic of Korea", 2020, Decimal('93.33')),
#  ('Japan', 2020, Decimal('99.00')),
#  ('Mongolia', 2020, Decimal('81.00')),
#  ('Republic of Korea', 2020, Decimal('100.00')),
#  ('Brunei Darussalam', 2020, Decimal('100.00')),
# ...

# %%
# %%sql
# SELECT
# Country_name,
# Time_period,
# pct_managed_drinking_water_services AS pct_access_to_water
# FROM
# Access_to_Basic_Services
# ORDER BY pct_access_to_water
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 10 rows affected.
# [('Central African Republic', 2020, Decimal('38.33')),
#  ('Central African Republic', 2019, Decimal('39.33')),
#  ('Central African Republic', 2018, Decimal('40.67')),
#  ('Central African Republic', 2017, Decimal('41.33')),
#  ('Central African Republic', 2016, Decimal('42.67')),
#  ('Central African Republic', 2015, Decimal('44.00')),
#  ('Democratic Republic of the Congo', 2015, Decimal('45.33')),
#  ('Democratic Republic of the Congo', 2016, Decimal('45.67')),
#  ('Democratic Republic of the Congo', 2017, Decimal('46.00')),
#  ('South Sudan', 2015, Decimal('46.33'))]

# %%
#Answer:Central African Republic, Democratic Republic of Congo and South Sudan.

# %% [markdown]
# # Using logical and comparison operator

# %%
# %%sql
#
# SELECT
# Country_name,
# Time_period,
# Pct_managed_drinking_water_services,
# Pct_managed_sanitation_services,
# Est_population_in_millions,
# Est_gdp_in_billions
#
# FROM
# Access_to_Basic_Services
#
# WHERE
# (Country_name = 'Nigeria'
# OR Country_name = 'Ethiopia'
# OR Country_name = 'Congo'
# OR Country_name = 'Egypt'
# OR Country_name = 'Tanzania'
# OR Country_name = 'Kenya'
# OR Country_name = 'South Africa')
# AND Time_period BETWEEN 2019 and 2020;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 12 rows affected.
# [('Egypt', 2019, Decimal('99.33'), Decimal('97.00'), None, None),
#  ('Egypt', 2020, Decimal('99.33'), Decimal('97.67'), None, None),
#  ('Ethiopia', 2019, Decimal('57.00'), Decimal('11.67'), Decimal('114.120594'), Decimal('95.91')),
#  ('Ethiopia', 2020, Decimal('58.00'), Decimal('11.67'), Decimal('117.190911'), Decimal('107.66')),
#  ('Kenya', 2019, Decimal('66.33'), Decimal('33.33'), Decimal('50.951450'), Decimal('100.38')),
#  ('Kenya', 2020, Decimal('67.00'), Decimal('33.67'), Decimal('51.985780'), Decimal('100.67')),
#  ('Congo', 2019, Decimal('69.00'), Decimal('17.67'), None, None),
#  ('Congo', 2020, Decimal('69.00'), Decimal('17.67'), None, None),
#  ('South Africa', 2019, Decimal('91.67'), Decimal('78.00'), Decimal('58.087055'), Decimal('388.53')),
#  ('South Africa', 2020, Decimal('92.00'), Decimal('78.67'), Decimal('58.801927'), Decimal('337.62')),
# ...

# %% [markdown]
# # Streamlining with the IN Operator

# %%
# %%sql
# SELECT
# Country_name,
# Time_period,
# Pct_managed_drinking_water_services,
# Pct_managed_sanitation_services,
# Est_population_in_millions,
# Est_gdp_in_billions
# FROM
# Access_to_Basic_Services
# WHERE
# Country_name IN ('Nigeria',
#                          'Ethiopia',
#                          'Congo',
#                          'Egypt',
#                          'Tanzania',
#                          'Kenya',
#                          'South Africa')
# AND Time_period BETWEEN 2019 and 2020;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 12 rows affected.
# [('Egypt', 2019, Decimal('99.33'), Decimal('97.00'), None, None),
#  ('Egypt', 2020, Decimal('99.33'), Decimal('97.67'), None, None),
#  ('Ethiopia', 2019, Decimal('57.00'), Decimal('11.67'), Decimal('114.120594'), Decimal('95.91')),
#  ('Ethiopia', 2020, Decimal('58.00'), Decimal('11.67'), Decimal('117.190911'), Decimal('107.66')),
#  ('Kenya', 2019, Decimal('66.33'), Decimal('33.33'), Decimal('50.951450'), Decimal('100.38')),
#  ('Kenya', 2020, Decimal('67.00'), Decimal('33.67'), Decimal('51.985780'), Decimal('100.67')),
#  ('Congo', 2019, Decimal('69.00'), Decimal('17.67'), None, None),
#  ('Congo', 2020, Decimal('69.00'), Decimal('17.67'), None, None),
#  ('South Africa', 2019, Decimal('91.67'), Decimal('78.00'), Decimal('58.087055'), Decimal('388.53')),
#  ('South Africa', 2020, Decimal('92.00'), Decimal('78.67'), Decimal('58.801927'), Decimal('337.62')),
# ...

# %% [markdown]
# # Combining Multiple Conditions

# %%
# %%sql
#
# SELECT
# Region,
# Country_name,
# Time_period,
# Pct_managed_drinking_water_services,
# Pct_managed_sanitation_services,
# Est_population_in_millions,
# Est_gdp_in_billions
# FROM
# Access_to_Basic_Services
# WHERE
# Pct_managed_sanitation_services <= 50
# AND Time_period = 2020;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 41 rows affected.
# [('Latin America and the Caribbean', 'Haiti', 2020, Decimal('65.00'), Decimal('36.00'), Decimal('11.306801'), Decimal('14.51')),
#  ('Northern Africa and Western Asia', 'Sudan', 2020, Decimal('62.33'), Decimal('40.33'), Decimal('44.440486'), Decimal('27.03')),
#  ('Oceania', 'Papua New Guinea', 2020, Decimal('56.67'), Decimal('27.67'), Decimal('9.749640'), Decimal('23.85')),
#  ('Oceania', 'Solomon Islands', 2020, Decimal('72.33'), Decimal('44.67'), Decimal('0.691191'), Decimal('1.54')),
#  ('Oceania', 'Kiribati', 2020, Decimal('77.00'), Decimal('45.33'), Decimal('0.126463'), Decimal('0.18')),
#  ('Sub-Saharan Africa', 'Burundi', 2020, Decimal('70.33'), Decimal('44.33'), Decimal('12.220227'), Decimal('2.65')),
#  ('Sub-Saharan Africa', 'Ethiopia', 2020, Decimal('58.00'), Decimal('11.67'), Decimal('117.190911'), Decimal('107.66')),
# ...

# %% [markdown]
# # Reading data across multiple tables

# %%
# %sql sqlite:///chinook.db
# Out:
# 'Connected: @chinook.db'

# %%
# %%sql
#
# --reading column from single table
#
# SELECT FirstName FROM customers
# LIMIT 10;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///chinook.db
# Done.
# [('Luís',),
#  ('Leonie',),
#  ('François',),
#  ('Bjørn',),
#  ('František',),
#  ('Helena',),
#  ('Astrid',),
#  ('Daan',),
#  ('Kara',),
#  ('Eduardo',)]

# %%
# %%sql
# /*reading column frommultiple table
# query to find out when each Chinook employee was hired*/
#
# SELECT FirstName, LastName, HireDate
# FROM employees;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///chinook.db
# Done.
# [('Andrew', 'Adams', '2002-08-14 00:00:00'),
#  ('Nancy', 'Edwards', '2002-05-01 00:00:00'),
#  ('Jane', 'Peacock', '2002-04-01 00:00:00'),
#  ('Margaret', 'Park', '2003-05-03 00:00:00'),
#  ('Steve', 'Johnson', '2003-10-17 00:00:00'),
#  ('Michael', 'Mitchell', '2003-10-17 00:00:00'),
#  ('Robert', 'King', '2004-01-02 00:00:00'),
#  ('Laura', 'Callahan', '2004-03-04 00:00:00')]

# %%
# %%sql
#
# --query that lists album titles and the corresponding artists.
#
#
# SELECT albums.Title, artists.Name
# FROM albums, artists
# LIMIT 10;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///chinook.db
# Done.
# [('For Those About To Rock We Salute You', 'AC/DC'),
#  ('For Those About To Rock We Salute You', 'Accept'),
#  ('For Those About To Rock We Salute You', 'Aerosmith'),
#  ('For Those About To Rock We Salute You', 'Alanis Morissette'),
#  ('For Those About To Rock We Salute You', 'Alice In Chains'),
#  ('For Those About To Rock We Salute You', 'Antônio Carlos Jobim'),
#  ('For Those About To Rock We Salute You', 'Apocalyptica'),
#  ('For Those About To Rock We Salute You', 'Audioslave'),
#  ('For Those About To Rock We Salute You', 'BackBeat'),
#  ('For Those About To Rock We Salute You', 'Billy Cobham')]

# %%
# %%sql
#
# SELECT albums.Title, artists.Name
# FROM albums, artists
# WHERE artists.Artistid = albums.Artistid;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///chinook.db
# Done.
# [('For Those About To Rock We Salute You', 'AC/DC'),
#  ('Balls to the Wall', 'Accept'),
#  ('Restless and Wild', 'Accept'),
#  ('Let There Be Rock', 'AC/DC'),
#  ('Big Ones', 'Aerosmith'),
#  ('Jagged Little Pill', 'Alanis Morissette'),
#  ('Facelift', 'Alice In Chains'),
#  ('Warner 25 Anos', 'Antônio Carlos Jobim'),
#  ('Plays Metallica By Four Cellos', 'Apocalyptica'),
#  ('Audioslave', 'Audioslave'),
#  ('Out Of Exile', 'Audioslave'),
#  ('BackBeat Soundtrack', 'BackBeat'),
#  ('The Best Of Billy Cobham', 'Billy Cobham'),
#  ('Alcohol Fueled Brewtality Live! [Disc 1]', 'Black Label Society'),
#  ('Alcohol Fueled Brewtality Live! [Disc 2]', 'Black Label Society'),
#  ('Black Sabbath', 'Black Sabbath'),
#  ('Black Sabbath Vol. 4 (Remaster)', 'Black Sabbath'),
#  ('Body Count', 'Body Count'),
#  ('Chemical Wedding', 'Bruce Dickinson'),
# ...

# %% [markdown]
# # Alaising and commenting in SQL

# %%
# %%sql
#
#
# /*Why use Alaise : When table or column names are long or difficult to understand, aliases come in handy
# Aliasing is the process of temporarily renaming a table or column within a table
# problem: unable to employee and customer column*/
#
# SELECT customers.FirstName, customers.LastName, employees.FirstName, employees.LastName
# FROM customers, employees
# WHERE customers.Country = "Canada"
# AND customers.SupportRepId = employees.EmployeeId;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///chinook.db
# Done.
# [('François', 'Tremblay', 'Jane', 'Peacock'),
#  ('Mark', 'Philips', 'Steve', 'Johnson'),
#  ('Jennifer', 'Peterson', 'Jane', 'Peacock'),
#  ('Robert', 'Brown', 'Jane', 'Peacock'),
#  ('Edward', 'Francis', 'Jane', 'Peacock'),
#  ('Martha', 'Silk', 'Steve', 'Johnson'),
#  ('Aaron', 'Mitchell', 'Margaret', 'Park'),
#  ('Ellie', 'Sullivan', 'Jane', 'Peacock')]

# %%
#when writing aliase for table and colum
#SELECT column_name AS alias_name FROM table_name;
#SELECT column_name FROM table_name alias_name;

# %%
# %%sql
# /* this query shows which customer
# & sales_agent lives in Canada*/
#
# SELECT c.FirstName AS 'customer_name' , c.LastName AS 'customer_surname',
# e.FirstName AS 'agent_name', e.LastName AS 'agent_surname'
# FROM customers c, employees e
# WHERE c.Country = "Canada"
# AND c.SupportRepId = e.EmployeeId;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///chinook.db
# Done.
# [('François', 'Tremblay', 'Jane', 'Peacock'),
#  ('Mark', 'Philips', 'Steve', 'Johnson'),
#  ('Jennifer', 'Peterson', 'Jane', 'Peacock'),
#  ('Robert', 'Brown', 'Jane', 'Peacock'),
#  ('Edward', 'Francis', 'Jane', 'Peacock'),
#  ('Martha', 'Silk', 'Steve', 'Johnson'),
#  ('Aaron', 'Mitchell', 'Margaret', 'Park'),
#  ('Ellie', 'Sullivan', 'Jane', 'Peacock')]

# %%
# %%sql
# --Write a query that returns the first names of all Chinook digital media store customers, limit = 10
#
#
# SELECT FirstName
# FROM customers
# LIMIT 10;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///chinook.db
# Done.
# [('Luís',),
#  ('Leonie',),
#  ('François',),
#  ('Bjørn',),
#  ('František',),
#  ('Helena',),
#  ('Astrid',),
#  ('Daan',),
#  ('Kara',),
#  ('Eduardo',)]

# %%
# %%sql
# --Write a query to find out when each Chinook employee was hired.
# SELECT FirstName, LastName, HireDate
# FROM employees
# LIMIT 10;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///chinook.db
# Done.
# [('Andrew', 'Adams', '2002-08-14 00:00:00'),
#  ('Nancy', 'Edwards', '2002-05-01 00:00:00'),
#  ('Jane', 'Peacock', '2002-04-01 00:00:00'),
#  ('Margaret', 'Park', '2003-05-03 00:00:00'),
#  ('Steve', 'Johnson', '2003-10-17 00:00:00'),
#  ('Michael', 'Mitchell', '2003-10-17 00:00:00'),
#  ('Robert', 'King', '2004-01-02 00:00:00'),
#  ('Laura', 'Callahan', '2004-03-04 00:00:00')]

# %%
# %%sql
#
# --Write a query that returns all Chinook employee information.
#
# SELECT *
# FROM employees;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///chinook.db
# Done.
# [(1, 'Adams', 'Andrew', 'General Manager', None, '1962-02-18 00:00:00', '2002-08-14 00:00:00', '11120 Jasper Ave NW', 'Edmonton', 'AB', 'Canada', 'T5K 2N1', '+1 (780) 428-9482', '+1 (780) 428-3457', 'andrew@chinookcorp.com'),
#  (2, 'Edwards', 'Nancy', 'Sales Manager', 1, '1958-12-08 00:00:00', '2002-05-01 00:00:00', '825 8 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 2T3', '+1 (403) 262-3443', '+1 (403) 262-3322', 'nancy@chinookcorp.com'),
#  (3, 'Peacock', 'Jane', 'Sales Support Agent', 2, '1973-08-29 00:00:00', '2002-04-01 00:00:00', '1111 6 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 5M5', '+1 (403) 262-3443', '+1 (403) 262-6712', 'jane@chinookcorp.com'),
#  (4, 'Park', 'Margaret', 'Sales Support Agent', 2, '1947-09-19 00:00:00', '2003-05-03 00:00:00', '683 10 Street SW', 'Calgary', 'AB', 'Canada', 'T2P 5G3', '+1 (403) 263-4423', '+1 (403) 263-4289', 'margaret@chinookcorp.com'),
# ...

# %%
# %%sql
#
# --write a SQL query that will return all customers who live in Germany.
#
# SELECT *
# FROM customers
# WHERE Country = "Germany"
# LIMIT 10;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///chinook.db
# Done.
# [(2, 'Leonie', 'Köhler', None, 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', '+49 0711 2842222', None, 'leonekohler@surfeu.de', 5),
#  (36, 'Hannah', 'Schneider', None, 'Tauentzienstraße 8', 'Berlin', None, 'Germany', '10789', '+49 030 26550280', None, 'hannah.schneider@yahoo.de', 5),
#  (37, 'Fynn', 'Zimmermann', None, 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', '+49 069 40598889', None, 'fzimmermann@yahoo.de', 3),
#  (38, 'Niklas', 'Schröder', None, 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', '+49 030 2141444', None, 'nschroder@surfeu.de', 3)]

# %%
# %%sql
#
# --write a SQL query that will return only firstname & lastname customers who live in Germany.
#
# SELECT FirstName, LastName
# FROM customers
# WHERE Country = "Germany";
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///chinook.db
# Done.
# [('Leonie', 'Köhler'),
#  ('Hannah', 'Schneider'),
#  ('Fynn', 'Zimmermann'),
#  ('Niklas', 'Schröder')]

# %%
# %%sql
#
# --write a SQL query that will return only firstname & lastname customers who live not Germany.
#
# SELECT FirstName, LastName
# FROM customers
# WHERE Country != "Germany";
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///chinook.db
# Done.
# [('Luís', 'Gonçalves'),
#  ('François', 'Tremblay'),
#  ('Bjørn', 'Hansen'),
#  ('František', 'Wichterlová'),
#  ('Helena', 'Holý'),
#  ('Astrid', 'Gruber'),
#  ('Daan', 'Peeters'),
#  ('Kara', 'Nielsen'),
#  ('Eduardo', 'Martins'),
#  ('Alexandre', 'Rocha'),
#  ('Roberto', 'Almeida'),
#  ('Fernanda', 'Ramos'),
#  ('Mark', 'Philips'),
#  ('Jennifer', 'Peterson'),
#  ('Frank', 'Harris'),
#  ('Jack', 'Smith'),
#  ('Michelle', 'Brooks'),
#  ('Tim', 'Goyer'),
#  ('Dan', 'Miller'),
#  ('Kathy', 'Chase'),
#  ('Heather', 'Leacock'),
#  ('John', 'Gordon'),
#  ('Frank', 'Ralston'),
#  ('Victor', 'Stevens'),
#  ('Richard', 'Cunningham'),
#  ('Patrick', 'Gray'),
#  ('Julia', 'Barnett'),
#  ('Robert', 'Brown'),
#  ('Edward', 'Francis'),
#  ('Martha', 'Silk'),
#  ('Aaron', 'Mitchell'),
#  ('Ellie', 'Sullivan'),
#  ('João', 'Fernandes'),
#  ('Madalena', 'Sampaio'),
#  ('Camille', 'Bernard'),
# ...

# %%
# %%sql
#
# --Write a query that returns all invoices that show USA purchases with a total greater than 10 dollars.
#
# SELECT *
# FROM invoices;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///chinook.db
# Done.
# [(1, 2, '2009-01-01 00:00:00', 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', 1.98),
#  (2, 4, '2009-01-02 00:00:00', 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', 3.96),
#  (3, 8, '2009-01-03 00:00:00', 'Grétrystraat 63', 'Brussels', None, 'Belgium', '1000', 5.94),
#  (4, 14, '2009-01-06 00:00:00', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', 8.91),
#  (5, 23, '2009-01-11 00:00:00', '69 Salem Street', 'Boston', 'MA', 'USA', '2113', 13.86),
#  (6, 37, '2009-01-19 00:00:00', 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', 0.99),
#  (7, 38, '2009-02-01 00:00:00', 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', 1.98),
#  (8, 40, '2009-02-01 00:00:00', '8, Rue Hanovre', 'Paris', None, 'France', '75002', 1.98),
#  (9, 42, '2009-02-02 00:00:00', '9, Place Louis Barthou', 'Bordeaux', None, 'France', '33000', 3.96),
# ...

# %%
# %%sql
#
# SELECT *
# FROM invoices
# WHERE BillingCountry = "USA" AND Total > 10;
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///chinook.db
# Done.
# [(5, 23, '2009-01-11 00:00:00', '69 Salem Street', 'Boston', 'MA', 'USA', '2113', 13.86),
#  (26, 19, '2009-04-14 00:00:00', '1 Infinite Loop', 'Cupertino', 'CA', 'USA', '95014', 13.86),
#  (82, 28, '2009-12-18 00:00:00', '302 S 700 E', 'Salt Lake City', 'UT', 'USA', '84102', 13.86),
#  (103, 24, '2010-03-21 00:00:00', '162 E Superior Street', 'Chicago', 'IL', 'USA', '60611', 15.86),
#  (124, 20, '2010-06-22 00:00:00', '541 Del Medio Avenue', 'Mountain View', 'CA', 'USA', '94040-111', 13.86),
#  (145, 16, '2010-09-23 00:00:00', '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', 13.86),
#  (201, 25, '2011-05-29 00:00:00', '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', 18.86),
#  (222, 21, '2011-08-30 00:00:00', '801 W 4th Street', 'Reno', 'NV', 'USA', '89503', 13.86),
# ...

# %%
# %%sql
#
# --Write a query that returns all stored information for Sales Support Agents who were hired on or after the 3rd of May 2003 and stay in Calgary.
#
# SELECT *
# FROM employees
# WHERE HireDate >= 2003-05-03 AND Title = "Sales Support Agent" AND City = "Calgary";
# Out:
#    mysql+pymysql://root:***@localhost:3306/united_nations
#  * sqlite:///chinook.db
# Done.
# [(3, 'Peacock', 'Jane', 'Sales Support Agent', 2, '1973-08-29 00:00:00', '2002-04-01 00:00:00', '1111 6 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 5M5', '+1 (403) 262-3443', '+1 (403) 262-6712', 'jane@chinookcorp.com'),
#  (4, 'Park', 'Margaret', 'Sales Support Agent', 2, '1947-09-19 00:00:00', '2003-05-03 00:00:00', '683 10 Street SW', 'Calgary', 'AB', 'Canada', 'T2P 5G3', '+1 (403) 263-4423', '+1 (403) 263-4289', 'margaret@chinookcorp.com'),
#  (5, 'Johnson', 'Steve', 'Sales Support Agent', 2, '1965-03-03 00:00:00', '2003-10-17 00:00:00', '7727B 41 Ave', 'Calgary', 'AB', 'Canada', 'T3B 1Y7', '1 (780) 836-9987', '1 (780) 836-9543', 'steve@chinookcorp.com')]
